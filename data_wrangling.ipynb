# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('attacks.csv', engine='python')
#importing the data from the csv file
#fixed an error by adding the engine='python' as an argument (thanks to Anton Neike)

# %%
#taking a first look at the table
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
data.shape
# Out:
# (25723, 24)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=25723, step=1)

# %%
#checking for missing values
#with boolean map
data.isna()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
#calculating sum of boolean map and assigning to variable nvalues
nvalues = data.isna().sum()

# %%
#calculating percentages of nvalues among all values in columns
nvalues[nvalues.gt(0)]/len(data)
# Out:
# Case Number               0.661704
# Date                      0.755005
# Year                      0.755083
# Type                      0.755161
# Country                   0.756949
# Area                      0.772694
# Location                  0.775998
# Activity                  0.776154
# Name                      0.763169
# Sex                       0.776970
# Age                       0.865062
# Injury                    0.756094
# Fatal (Y/N)               0.775959
# Time                      0.885394
# Species                   0.865335
# Investigator or Source    0.755666
# pdf                       0.755005
# href formula              0.755044
# href                      0.755005
# Case Number.1             0.755005
# Case Number.2             0.755005
# original order            0.754733
# Unnamed: 22               0.999961
# Unnamed: 23               0.999922
# dtype: float64

# %%
#all columns have more that 50% null values 
#last two columns almost 100% -> drop those columns

#assign percentages to the variable nvalues_ratios
nvalues_ratios = nvalues[nvalues.gt(0)]/len(data)

#filter for percentages over 90%
nvalues_ratios.loc[nvalues_ratios.gt(0.9)].index

#dropping the two columns
data2 = data.drop(columns=nvalues_ratios.loc[nvalues_ratios.gt(0.9)].index).copy()

data2
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#dropping rows with all null values 
data3 = data2.dropna(how = 'all')

# %%
data3
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#down to 8703 rows
#but what about rows with null values and a 0 as case number 

#data3.loc[data3['Case Number']== 0] -> doesn't work since column values 
#are type object, not numerical
data3.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# dtype: object

# %%
print(set(data3['Case Number']))
# Out:
# {nan, '2000.11.18', 'ND-0136', '1954.07.03', '2003.05.10', '1959.12.19.a', '2006.07.09.b', '1955.08.00.a', '2006.09.03.b', '2008.05.10', '1982.09.30.a', '1942.00.00.h', '1992.05.22', '2011.12.05', '1994.09.11.R', '1988.02.13', '1958.04.00', '2009.04.28', '1916.07.11', '1921.10.12', '1993.02.04', '1907.08.12.a..R', '1963.09.26', '2016.10.15', '1963.12.04.R', '1967.09.13', '2008.01.27', '1934.01.27', '1991.02.24', '1960.06.04', '1906.10.10.b.R', '1700.00.00.c', '1961.01.05', '2018.04.28.b', '2015.07.23.a', '1998.11.21', '2008.08.18', '1940.00.00.e', '1964.02.14.b', '1960.10.00.a', '1900.00.00.b', '1965.04.04.a', '1996.05.10', '1992.08.00', '2015.11.03', '1975.08.09', '1880.05.02.a', '2013.03.16.b', '2003.01.03', '1956.10.20', '1967.08.25', '1904.07.28', '1877.03.11', '1914.12.04.R', '1944.01.14', '1964.07.15', '1977.08.31', '2007.03.31.a', '1947.11.14.b', '2017.09.03.a', '1940.01.29', '1983.12.07', '2005.12.05.R', '2001.09.15.b', '1970.01.23.d', '1999.11.23', '2014.00.00.b', '1950.03.0
# ...

# %%
#replacing all . and - in column Case Number with empty string 

data3['Case Number'] = data3.loc[:,'Case Number'].str.replace('.', '').replace('-','')
print(set(data3['Case Number']))
# Out:
# {'19990129', nan, '18390000a', '20170617', '19641206', '20060201b', '20080724b', 'ND-0136', '20060709b', '20090118', '19591200', '19590802', '19270408', '19640927', '19001114', '20000302', '18580114R', '19840212', '20170602', '20170206a', '18741121', '19700802', '19930605', '19790301', '19500000b', '19130827R', '19440820', '19620215', '19310114', '20001104', '19391106', '19980830', '19000821', '19220320', '19151108', '19560000a', '19540704R', '20140727', '19260407', '20070905', '19550800a', '19950917', '19760000b', '19590810', '20071100', '19911126b', '20050814', '18971005R', '20040800', '18860617', '18491209', '20100530', '20110423', '20130826', '19610902R', '19340711', '19510219', '19960906a', '19930000a', '00000214', '19220617', '20010918', '19131230R', '19810308', '20160210', '20130618', '19940000a', '19040000c', '19461224R', '19120723', '18791224', '19511206', '19181100b', '19620118', '19611009', '19021110', '20160111R', '20120118b', '20090222', '19950821', '19301202', '20180113
# ...

# %%
#trying to replace the non-digits with empty string and than converting dtype of the column to integer - didn't work
data3['Case Number'] = data3['Case Number'].str.replace(r'\D+', '').astype('int')

#use to numeric instead
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ed3eefdc01f3> in <module>
#       1 #trying to replace the non-digits with empty string and than converting dtype of the column to integer - didn't work
# ----> 2 data3['Case Number'] = data3['Case Number'].str.replace(r'\D+', '').astype('int')
#       3
#       4 #use to numeric instead
#
# ~/opt/anaconda3/envs/matrix/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# ~/opt/anaconda3/envs/matrix/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...

# %%
#filling the na in column Case Number with 0, to filter later for 0 and drop these rows 

data3['Case Number'] = data3['Case Number'].fillna(0)
# Out:
# <ipython-input-16-5f9447a349d3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['Case Number'] = data3['Case Number'].fillna(0)

# %%
#replacing the non-digits with empty string 
data3['Case Number'] = data3['Case Number'].str.replace(r'\D+', '')
print(set(data3['Case Number']))
# Out:
# {'19990129', nan, '', '20010412', '20170617', '19641206', '18951121', '20090118', '19591200', '19590802', '18810000', '19270408', '19640927', '19001114', '20000302', '19840212', '20170602', '18741121', '19700802', '19930605', '19980308', '19790301', '19650404', '18670822', '19440820', '19620215', '19310114', '20001104', '19820724', '19391106', '19980830', '19000821', '20160111', '19220320', '19151108', '20140727', '19260407', '20180425', '20070905', '19950917', '19590810', '20071100', '20050814', '20040800', '18860617', '18491209', '20100530', '20110423', '20130826', '18521009', '19340711', '19310728', '19510219', '00000214', '19220617', '19740213', '20010918', '19810308', '20160210', '20130618', '19120723', '18791224', '19511206', '20041009', '19421100', '19620118', '19611009', '19021110', '19021101', '20090222', '19950821', '19301202', '20180113', '20051006', '20081022', '19540115', '19240422', '20130105', '0086', '19941113', '18670000', '20080816', '19510817', '19490729', '1981051
# ...

# %%
#replacing 'Nan' in column Case Number with empty string 
data3['Case Number'] = data3['Case Number'].str.replace( 'NaN' , '')
data3
# Out:
# <ipython-input-18-01419702c912>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['Case Number'] = data3['Case Number'].str.replace( 'NaN' , '')
#       Case Number         Date    Year        Type    Country  \
# 0        20180625  25-Jun-2018  2018.0     Boating        USA
# 1        20180618  18-Jun-2018  2018.0  Unprovoked        USA
# 2        20180609  09-Jun-2018  2018.0     Invalid        USA
# 3        20180608  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4        20180604  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# ...

# %%
data4 = data3.loc[~(data3['Case Number'] == "0") ]

# %%
data4
# Out:
#       Case Number         Date    Year        Type             Country  \
# 0        20180625  25-Jun-2018  2018.0     Boating                 USA
# 1        20180618  18-Jun-2018  2018.0  Unprovoked                 USA
# 2        20180609  09-Jun-2018  2018.0     Invalid                 USA
# 3        20180608  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4        20180604  04-Jun-2018  2018.0    Provoked              MEXICO
# ...           ...          ...     ...         ...                 ...
# 6298         0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299         0003    1900-1905     0.0  Unprovoked                 USA
# 6300         0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301         0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
# 25722                      NaN     NaN         NaN                 NaN
#
#                     Area                             Location      Activity  \
# ...

# %%
#dropping again row or rows with all null values (see above row 25722)
data4 = data4.dropna(how = 'all')

# %%
data4
# Out:
#       Case Number         Date    Year        Type             Country  \
# 0        20180625  25-Jun-2018  2018.0     Boating                 USA
# 1        20180618  18-Jun-2018  2018.0  Unprovoked                 USA
# 2        20180609  09-Jun-2018  2018.0     Invalid                 USA
# 3        20180608  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4        20180604  04-Jun-2018  2018.0    Provoked              MEXICO
# ...           ...          ...     ...         ...                 ...
# 6298         0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299         0003    1900-1905     0.0  Unprovoked                 USA
# 6300         0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301         0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
# 25722                      NaN     NaN         NaN                 NaN
#
#                     Area                             Location      Activity  \
# ...

# %%
#checking again for null values in dataframe with boolean map
data4.isna()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 6298         False  False  False  False    False  False      True     False
# 6299         False  False  False  False    False  False     False     False
# 6300         False  False  False  False    False   True     False      True
# 6301         False  False  False  False    False  False     False     False
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
#calculating again sum of boolean map and assigning to variable nvalues2
nvalues2 = data4.isna().sum()

# %%
#calculating new percentages of nvalues2 among all values in columns
nvalues2[nvalues2.gt(0)]/len(data4)
# Out:
# Case Number               0.000159
# Date                      0.000159
# Year                      0.000476
# Type                      0.000793
# Country                   0.008091
# Area                      0.072347
# Location                  0.085832
# Activity                  0.086467
# Name                      0.033476
# Sex                       0.089799
# Age                       0.449310
# Injury                    0.004601
# Fatal (Y/N)               0.085673
# Time                      0.532286
# Species                   0.450420
# Investigator or Source    0.002856
# pdf                       0.000159
# href formula              0.000317
# href                      0.000159
# Case Number.1             0.000159
# Case Number.2             0.000159
# original order            0.000159
# dtype: float64

# %%
#looks like most null values have been dropped 
#columns Age, Time and Species could need further examination

data4.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# dtype: object

# %%
#can we change the data type for a few columns?
# maybe for the CASE NUMBER 
data4['Case Number'] = pd.to_numeric(data4['Case Number'])

# %%
data4.dtypes
# Out:
# Case Number               float64
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# dtype: object

# %%
# not a unique identifier any more 
data4['Case Number'].is_unique
# Out:
# False

# %%
data4['original order'].unique
# Out:
# <bound method Series.unique of 0        6303.0
# 1        6302.0
# 2        6301.0
# 3        6300.0
# 4        6299.0
#           ...
# 6298        5.0
# 6299        4.0
# 6300        3.0
# 6301        2.0
# 25722       NaN
# Name: original order, Length: 6303, dtype: float64>

# %%
data4['original order'].is_unique
# Out:
# False

# %%
#there is often a male or female in the Name column
data4
# Out:
#        Case Number         Date    Year        Type             Country  \
# 0       20180625.0  25-Jun-2018  2018.0     Boating                 USA
# 1       20180618.0  18-Jun-2018  2018.0  Unprovoked                 USA
# 2       20180609.0  09-Jun-2018  2018.0     Invalid                 USA
# 3       20180608.0  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4       20180604.0  04-Jun-2018  2018.0    Provoked              MEXICO
# ...            ...          ...     ...         ...                 ...
# 6298           4.0  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299           3.0    1900-1905     0.0  Unprovoked                 USA
# 6300           2.0    1883-1889     0.0  Unprovoked              PANAMA
# 6301           1.0    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
# 25722          NaN          NaN     NaN         NaN                 NaN
#
#                     Area                             Location      Activity  \
# ...

# %%
data5 = data4.copy()

# %%
#deleting those values and replacing with nan
useless_words = ['female', 'male']

data5['Name'] = np.where(data4['Name'].isin(useless_words), np.nan, data4['Name'])

# %%
data5.head(20)
# Out:
#     Case Number                  Date    Year          Type       Country  \
# 0    20180625.0           25-Jun-2018  2018.0       Boating           USA
# 1    20180618.0           18-Jun-2018  2018.0    Unprovoked           USA
# 2    20180609.0           09-Jun-2018  2018.0       Invalid           USA
# 3    20180608.0           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4    20180604.0           04-Jun-2018  2018.0      Provoked        MEXICO
# 5    20180603.0           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6    20180603.0           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7    20180527.0           27-May-2018  2018.0    Unprovoked           USA
# 8    20180526.0           26-May-2018  2018.0    Unprovoked           USA
# 9    20180526.0           26-May-2018  2018.0    Unprovoked           USA
# 10   20180524.0           24-May-2018  2018.0      Provoked     AUSTRALIA
# 11   20180521.0           21-May-2018  2018.0    Unprovoked           USA
# ...

# %%
#trying to convert date column to into datetime format 
data5['Date'] = pd.to_datetime(data5['Date'], infer_datetime_format = True, errors = 'coerce')

# %%
data5.head(10)
# Out:
#    Case Number       Date    Year        Type    Country             Area  \
# 0   20180625.0 2018-06-25  2018.0     Boating        USA       California
# 1   20180618.0 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2   20180609.0 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3   20180608.0 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4   20180604.0 2018-06-04  2018.0    Provoked     MEXICO           Colima
# 5   20180603.0 2018-06-03  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6   20180603.0 2018-06-03  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7   20180527.0 2018-05-27  2018.0  Unprovoked        USA          Florida
# 8   20180526.0 2018-05-26  2018.0  Unprovoked        USA          Florida
# 9   20180526.0 2018-05-26  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# 0                        Oceanside, San Diego County      Paddling
# ...

# %%
#checking datatype 
data5.dtypes
# Out:
# Case Number                      float64
# Date                      datetime64[ns]
# Year                             float64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Injury                            object
# Fatal (Y/N)                       object
# Time                              object
# Species                           object
# Investigator or Source            object
# pdf                               object
# href formula                      object
# href                              object
# Case Number.1                     object
# Case Number.2                     object
# original order                   float64
# dtype: object

# %%
#can we check if year in Date column is the same as year in column Year ?
data6 = data5.copy()

# %%
# data3['Case Number'] = data3.loc[:,'Case Number'].str.replace('.', '')
# data3['Case Number'] = data3['Case Number'].str.replace(r'\D+', '')
data6['Time'] = data6.loc[:,'Time'].str.replace('h', ':')

# %%
data6.head()
# Out:
#    Case Number       Date    Year        Type    Country             Area  \
# 0   20180625.0 2018-06-25  2018.0     Boating        USA       California
# 1   20180618.0 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2   20180609.0 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3   20180608.0 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4   20180604.0 2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing              NaN    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
#checking if Time column can be converted to datetime.time format

data6['Time'] = pd.to_datetime(data6['Time'], errors = 'ignore' , infer_datetime_format = True)

# %%
data6.head(50)
# Out:
#     Case Number       Date    Year          Type        Country  \
# 0    20180625.0 2018-06-25  2018.0       Boating            USA
# 1    20180618.0 2018-06-18  2018.0    Unprovoked            USA
# 2    20180609.0 2018-06-09  2018.0       Invalid            USA
# 3    20180608.0 2018-06-08  2018.0    Unprovoked      AUSTRALIA
# 4    20180604.0 2018-06-04  2018.0      Provoked         MEXICO
# 5    20180603.0 2018-06-03  2018.0    Unprovoked      AUSTRALIA
# 6    20180603.0 2018-06-03  2018.0    Unprovoked         BRAZIL
# 7    20180527.0 2018-05-27  2018.0    Unprovoked            USA
# 8    20180526.0 2018-05-26  2018.0    Unprovoked            USA
# 9    20180526.0 2018-05-26  2018.0    Unprovoked            USA
# 10   20180524.0 2018-05-24  2018.0      Provoked      AUSTRALIA
# 11   20180521.0 2018-05-21  2018.0    Unprovoked            USA
# 12   20180513.0 2018-05-13  2018.0    Unprovoked            USA
# 13   20180513.0 2018-05-13  2018.0       Invalid        ENGLAND
# ...

# %%
data6.dtypes
# Out:
# Case Number                      float64
# Date                      datetime64[ns]
# Year                             float64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Injury                            object
# Fatal (Y/N)                       object
# Time                              object
# Species                           object
# Investigator or Source            object
# pdf                               object
# href formula                      object
# href                              object
# Case Number.1                     object
# Case Number.2                     object
# original order                   float64
# dtype: object
